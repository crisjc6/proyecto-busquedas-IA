# %%
import matplotlib.pyplot as plt
import networkx as nx
GRAPH = {\
            'Arad': {'Sibiu': 140, 'Zerind': 75, 'Timisoara': 118},\
            'Zerind': {'Arad': 75, 'Oradea': 71},\
            'Oradea': {'Zerind': 71, 'Sibiu': 151},\
            'Sibiu': {'Arad': 140, 'Oradea': 151, 'Fagaras': 99, 'Rimnicu': 80},\
            'Timisoara': {'Arad': 118, 'Lugoj': 111},\
            'Lugoj': {'Timisoara': 111, 'Mehadia': 70},\
            'Mehadia': {'Lugoj': 70, 'Drobeta': 75},\
            'Drobeta': {'Mehadia': 75, 'Craiova': 120},\
            'Craiova': {'Drobeta': 120, 'Rimnicu': 146, 'Pitesti': 138},\
            'Rimnicu': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},\
            'Fagaras': {'Sibiu': 99, 'Bucharest': 211},\
            'Pitesti': {'Rimnicu': 97, 'Craiova': 138, 'Bucharest': 101},\
            'Bucharest': {'Fagaras': 211, 'Pitesti': 101, 'Giurgiu': 90, 'Urziceni': 85},\
            'Giurgiu': {'Bucharest': 90},\
            'Urziceni': {'Bucharest': 85, 'Vaslui': 142, 'Hirsova': 98},\
            'Hirsova': {'Urziceni': 98, 'Eforie': 86},\
            'Eforie': {'Hirsova': 86},\
            'Vaslui': {'Iasi': 92, 'Urziceni': 142},\
            'Iasi': {'Vaslui': 92, 'Neamt': 87},\
            'Neamt': {'Iasi': 87}\
        }
G=nx.Graph(GRAPH)
G

# %%
nx.draw(G, with_labels=True)

# %%
pos = nx.spring_layout(G, iterations=200)
print(G.edges(data= True))
nx.draw(G, pos, cmap=plt.cm.Blues, with_labels=True)
plt.show()
# Out:
# [('Arad', 'Sibiu', {}), ('Arad', 'Zerind', {}), ('Arad', 'Timisoara', {}), ('Zerind', 'Oradea', {}), ('Oradea', 'Sibiu', {}), ('Sibiu', 'Fagaras', {}), ('Sibiu', 'Rimnicu', {}), ('Timisoara', 'Lugoj', {}), ('Lugoj', 'Mehadia', {}), ('Mehadia', 'Drobeta', {}), ('Drobeta', 'Craiova', {}), ('Craiova', 'Rimnicu', {}), ('Craiova', 'Pitesti', {}), ('Rimnicu', 'Pitesti', {}), ('Fagaras', 'Bucharest', {}), ('Pitesti', 'Bucharest', {}), ('Bucharest', 'Giurgiu', {}), ('Bucharest', 'Urziceni', {}), ('Urziceni', 'Vaslui', {}), ('Urziceni', 'Hirsova', {}), ('Hirsova', 'Eforie', {}), ('Vaslui', 'Iasi', {}), ('Iasi', 'Neamt', {})]

# %%
import networkx as nx
import random
import matplotlib.pyplot as plt


def printGraph(G, pos):
    print(G.edges)
    print('posicion', pos)
    labels = nx.get_edge_attributes(G, 'weight')
    # positions for all nodes
    # nodes
    nx.draw_networkx_nodes(G, pos, node_size=700)
    # edges
    nx.draw_networkx_edges(G, pos, width=4)
    # labels
    nx.draw_networkx_labels(G, pos, font_size=20, font_family='sans-serif')
    labels = nx.get_edge_attributes(G, 'weight')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
    plt.axis('off')
    plt.show()


# grafo de n nodos donde la probabilidad de que un eje exista es de p
n = 5
G = nx.complete_graph(n)
for (u, v, w) in G.edges(data=True):
    w['weight'] = random.randint(1,4)
print(G.edges(data= True))
pos = nx.shell_layout(G)
# Y MIREN! tienen la solucion secuencial del ejercicio para testear validez!
# igual usen el de catedra tambien
T = nx.minimum_spanning_tree(G)
printGraph(T, pos)
# Out:
# [(0, 1, {'weight': 2}), (0, 2, {'weight': 1}), (0, 3, {'weight': 1}), (0, 4, {'weight': 3}), (1, 2, {'weight': 3}), (1, 3, {'weight': 2}), (1, 4, {'weight': 4}), (2, 3, {'weight': 3}), (2, 4, {'weight': 4}), (3, 4, {'weight': 3})]
# [(0, 2), (0, 3), (0, 1), (0, 4)]
# posicion {0: array([1.00000000e+00, 2.38418583e-08]), 1: array([0.30901697, 0.95105654]), 2: array([-0.80901706,  0.58778518]), 3: array([-0.80901694, -0.58778536]), 4: array([ 0.30901712, -0.95105648])}
